# %% [markdown]
# **Project Title: Marketing Campaign Performance Insights**

# %% [markdown]
# **Project Steps and Objectives:**
#
# **1) Load the Dataset**
#
# **➢ Read the marketing campaign data from the CSV file into a pandas DataFrame.**

# %%
import numpy as np
import pandas as pd

# %%
#read the dataset

data = pd.read_csv('marketing_campaign.csv')
data
# Out:
#        Campaign_ID              Company Campaign_Type Target_Audience  \
# 0                1             TechCorp         Email     Women 25-34
# 1                2  Innovate Industries    Influencer     Women 35-44
# 2                3       NexGen Systems  Social Media     Women 25-34
# 3                4  Innovate Industries         Email     Women 25-34
# 4                5  Data Tech Solutions    Influencer       Men 25-34
# ...            ...                  ...           ...             ...
# 22024        22025  Data Tech Solutions        Search       Men 18-24
# 22025        22026  Data Tech Solutions  Social Media       Men 18-24
# 22026        22027             TechCorp    Influencer     Women 25-34
# 22027        22028  Data Tech Solutions        Search       Men 18-24
# 22028        22029       NexGen Systems        Search       Men 18-24
#
#       Duration Channel_Used  Conversion_Rate  Acquisition_Cost     ROI  \
# ...

# %% [markdown]
# **2) Descriptive Analysis**
#
# **Basic Structure**
#
# **➢ Print the first few rows of the dataset to get an overview of the data.**

# %%
# first 10 rows of the dataset

data.head(10)
# Out:
#    Campaign_ID              Company Campaign_Type Target_Audience Duration  \
# 0            1             TechCorp         Email     Women 25-34  30 days
# 1            2  Innovate Industries    Influencer     Women 35-44  45 days
# 2            3       NexGen Systems  Social Media     Women 25-34  45 days
# 3            4  Innovate Industries         Email     Women 25-34  45 days
# 4            5  Data Tech Solutions    Influencer       Men 25-34  30 days
# 5            6       NexGen Systems  Social Media     Women 35-44  15 days
# 6            7    Alpha Innovations       Display     Women 35-44  30 days
# 7            8       NexGen Systems    Influencer     Women 25-34  30 days
# 8            9  Innovate Industries         Email     Women 25-34  45 days
# 9           10       NexGen Systems         Email       Men 25-34  60 days
#
#   Channel_Used  Conversion_Rate  Acquisition_Cost      ROI          Location  \
# ...

# %% [markdown]
# **➢ Obtain the number of rows and columns in the dataset.**

# %%
data.shape
print('Number of rows and columns:{}'.format(data.shape))
# Out:
# Number of rows and columns:(22029, 16)

# %% [markdown]
# **Summary:**It shows the total rows and columns of the dataframe

# %% [markdown]
# **➢ Get a concise summary of the dataset, including the data types and non-null values.**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22029 entries, 0 to 22028
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Campaign_ID       22029 non-null  int64
#  1   Company           22029 non-null  object
#  2   Campaign_Type     22029 non-null  object
#  3   Target_Audience   22029 non-null  object
#  4   Duration          22029 non-null  object
#  5   Channel_Used      22029 non-null  object
#  6   Conversion_Rate   22029 non-null  float64
#  7   Acquisition_Cost  22029 non-null  int64
#  8   ROI               22029 non-null  float64
#  9   Location          22029 non-null  object
#  10  Language          22029 non-null  object
#  11  Clicks            22029 non-null  int64
#  12  Impressions       22029 non-null  int64
#  13  Engagement_Score  22029 non-null  int64
#  14  Customer_Segment  22029 non-null  object
#  15  Date              22029 non-null  object
# ...

# %% [markdown]
# **Summary :** It shows all the detail of the columns

# %% [markdown]
# **➢ Generate descriptive statistics for numerical columns.**

# %%
data.describe()
# Out:
#         Campaign_ID  Conversion_Rate  Acquisition_Cost           ROI  \
# count  22029.000000     22029.000000      22029.000000  22029.000000
# mean   11015.000000         4.757232       5522.740842    182.863648
# std     6359.368876         0.960393       2597.666260    301.619721
# min        1.000000         2.015723       1000.000000    -98.300000
# 25%     5508.000000         4.130705       3286.000000     -4.080000
# 50%    11015.000000         4.761527       5525.000000     93.650000
# 75%    16522.000000         5.429335       7766.000000    247.310000
# max    22029.000000         7.469907       9999.000000   3109.790000
#
#              Clicks   Impressions  Engagement_Score
# count  22029.000000  22029.000000      22029.000000
# mean    2223.807572  50610.402787          6.582323
# std     1394.166380  28542.979123          1.458804
# min       30.000000   1001.000000          4.000000
# 25%     1067.000000  25804.000000          5.000000
# ...

# %% [markdown]
# **Summary:**It shows the statistical summary of the numerical coumn of the dataframe

# %% [markdown]
# **Data Exploration:**
#
# **➢ Print the number of unique Campaign_ID values in the dataset.**

# %%
# number of unique values in Campaign_ID

unique_values = data['Campaign_ID'].nunique()

print('Number of Unique_values in campaign_ID:{}'.format(unique_values))
# Out:
# Number of Unique_values in campaign_ID:22029

# %% [markdown]
# **Summary :** It shows unique value of Campaign_ID column

# %% [markdown]
# **➢ List the unique values of the Location and Customer_Segment columns.**

# %%
# unique values of location and customer_segment columns.

unique_values_location= data['Location'].unique()
unique_values_customer_segment=data['Customer_Segment'].unique()

print('Number of unique_values_Loaction:{}'.format(unique_values_location))
print('Number of unique_values_Customer_segment:{}'.format(unique_values_customer_segment))
# Out:
# Number of unique_values_Loaction:['Houston' 'Washington, D.C.' 'Miami' 'Seattle' 'Chicago' 'Los Angeles'
#  'Atlanta' 'Dallas' 'New York' 'San Francisco']
# Number of unique_values_Customer_segment:['Tech Enthusiasts' 'Foodies' 'Fashionistas' 'Outdoor Adventurers'
#  'Health & Wellness']

# %% [markdown]
# **Summary :** It shows unique values of Location and cutomer_segment columns

# %% [markdown]
# **➢** **Count the occurrences of each category in the Campaign_Type and Channel_Used and columns.**

# %%
# value count of campaign_type

compaign_type_counts=data['Campaign_Type'].value_counts()
channel_used_counts=data['Channel_Used'].value_counts()

print('compaign type counts:{}'.format(compaign_type_counts))
print('\n channel used counts:{}'.format(channel_used_counts))
# Out:
# compaign type counts:Campaign_Type
# Display         4450
# Search          4441
# Social Media    4412
# Email           4388
# Influencer      4338
# Name: count, dtype: int64
#
#  channel used counts:Channel_Used
# Facebook      3742
# Google Ads    3694
# Website       3688
# Instagram     3649
# YouTube       3632
# Email         3624
# Name: count, dtype: int64

# %% [markdown]
# **Summary :** It shows the value counts of Campaign_Type and Channel_Used columns

# %% [markdown]
# **3) Exploratory Data Analysis (EDA) and Visualization**
#
# **Campaign Performance :**
#
# **➢ Plot a scatter plot to visualize the relationship between Acquisition_Cost and ROI.**

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# %%
# relationship between Acquisition_cost vs ROI using Scotter plot

plt.figure(figsize=(10,8),facecolor='pink')
plt.scatter(data['Acquisition_Cost'],data['ROI'],color='purple')
plt.title('Acquisition_cost vs ROI',fontsize=25,color='red')
plt.xlabel('Acquisition_Cost',color='red',fontsize=25)
plt.ylabel('ROI',color='red',fontsize=25)
plt.grid(True)
plt.show()

# %% [markdown]
# **Explanation:**
#
# * It shows the relationship between Acquisition_cost and ROI.
# * X - axis represents Acquitision_cost.
# * Y - axis represents ROI(Return on Ivestment).
# * Acqutision_cost is high the ROI is low so there is a negative correlation between these two columns.

# %% [markdown]
# **➢ Create a bar chart to visualize the average Conversion_Rate for different Channel_Used, categorized by Campaign_Type.**

# %%
#average Conversion_Rate for different Channel_Used, categorized by Campaign_Type.

plt.figure(figsize=(10,6),facecolor='pink')
sns.barplot(data,x='Channel_Used',y='Conversion_Rate',hue='Campaign_Type',estimator='mean', palette='Set1')
plt.title('Average Conversion_Rate for different Channel_Used, categorized by Campaign_Type',fontsize=24,color='red')
plt.xlabel('Channel_Used',color='red',fontsize=25)
plt.ylabel('Average Conversion_Rate',color='red',fontsize=25)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Explanation:**
#
# * X-axis: Represents the different Channel_Used for marketing campaigns
#
# * Y-axis: Represents the average Conversion_Rate for each channel and campaign type combination.
#
# * Bars: Each bar represents the average conversion rate for a specific channel and campaign type.
#
#
# * Colors: Different colors represent different Campaign_Type categories.
#
# Using this bar chart we understand the average conversion_rate how differ by the channel_used of campaign_type.compare with all channel use, youtube users of all campign_type is equal of the highest average coversion_rate

# %% [markdown]
# **➢** **Visualize the distribution of Engagement_Score across different Campaign_Type using a box plot.**

# %%
#Engagement_Score across different Campaign_Type using a box plot.
data.groupby('Campaign_Type')['Engagement_Score'].mean()
plt.figure(figsize=(10,6),facecolor='pink')
sns.boxplot(data,x='Campaign_Type',y='Engagement_Score',hue='Campaign_Type')
plt.title('Engagement_Score vs Campaign_Type',fontsize=25,color='red')
plt.xlabel('Campaign_Type',fontsize=25,color='red')
plt.ylabel('Engagement_Score',fontsize=25,color='red')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Explanation:**
#
# * X-axis represents Campaign_type
# * Y-axis represents Engagement_Score
# * This box plot shows the distribution of the X and Y axis
# * There is no outliers in the camapign_type
# *  All the campaign_Types are equal for the avberage engagement score

# %% [markdown]
# **➢Analyze the average ROI by Company using a bar chart to compare the profitability of campaigns conducted by different companies**

# %%
#analyze average ROI by company using barplot

plt.figure(figsize=(10,6),facecolor='pink')
sns.barplot(data,x='Company',y='ROI',hue='Campaign_Type', estimator='mean',palette='Set2')
plt.title('Average ROI by Company',fontsize=25,color='red')
plt.xlabel('Company',fontsize=25,color='red')
plt.ylabel('ROI',fontsize=25,color='red')
plt.show()

# %% [markdown]
# **Expalnation:**
#
# * X-axis represents Comapny
# * Y-axis represents ROI
# * It shows the barplot of the average ROI by Company with campaign_type
# * In this visual we understand the NexGen Systems company get high amount of average ROI in the campaign_type of Display
# * The Data Tech Solutions get low average amount of ROI in the campaign_type of search comparing with other.

# %% [markdown]
# **➢ Examine the correlation between Engagement_Score and Conversion_Rate using a heatmap.**

# %%
#correlation between Engagement_Score and Conversion_Rate using a heatmap

correlation=data[['Engagement_Score','Conversion_Rate']].corr()
plt.figure(figsize=(10,6),facecolor='pink')
sns.heatmap(correlation,annot=True,cmap='coolwarm')
plt.title('Correlation between Engagement_Score and Conversion_Rate using a heatmap',color='green',fontsize=20)
plt.show()

# %% [markdown]
# **Explanation :**
#
# *  The above heat map shows the correlation between the conversion_rate and enaggement_score.
# *   The engagement score is high the conversion_rate aslo getting high
# * So there is a positive correlation between these two columns

# %% [markdown]
# **Customer Segmentation**
#
# **➢ Create a count plot to visualize the distribution of Target_Audience.**

# %%
#count plot to visualize the distribution of Target_Audience.
plt.figure(figsize=(10,6),facecolor='pink')
sns.countplot(x='Target_Audience',data=data,hue='Channel_Used',palette='Set3')
plt.title('Count plot to visualize the distribution of Target_Audience',color='red',fontsize=20)
plt.xlabel('Target_Audience',color='red',fontsize=20)
plt.ylabel('Count',color='red',fontsize=20)
plt.show()

# %% [markdown]
# **Expalnation:**
#
# * X-axis represents Target_Audience.
# * Y-axis represents Count
# * This barplot shows the distribution of target audience with differnt channel used.
# * Comapring with other audience 25 to 34 age womens count highly used the channel especailly face book and website.

# %% [markdown]
# **➢ Identify which Customer_Segment has the highest Conversion_Rate for each Language using a bar chart.**

# %%
# find the highest conversion_rate for each language in which customer segment using by bar chart

plt.figure(figsize=(10,6),facecolor='pink')
sns.barplot(data,x='Customer_Segment',y='Conversion_Rate',hue='Language',palette='Set2')
plt.title('The highest Conversion_Rate of Customer_Segment  for each Language',color='red',fontsize=20)
plt.xlabel('Customer_Segment',color='red',fontsize=20)
plt.ylabel('Conversion_Rate',color='red',fontsize=20)
plt.show()

# %% [markdown]
# **Expalnation:**
#
# * X-axis represents Customer_segment.
# * Y-axis represents Conversion_rate
# * It shows the highest conversion_rate of customer_segment for the languages
# * The highest conversion_rate is equal for all the customer_segment in the language of English

# %% [markdown]
# **➢ Visualize the distribution of Acquisition_Cost across each Customer_Segment,categorized by Channel_Used, using a box plot.**

# %%
#distribution of Acquisition_Cost across each Customer_Segment by Channel_Used using a box plot.

plt.figure(figsize=(10,6),facecolor='pink')
sns.boxplot(data,x='Customer_Segment',y='Acquisition_Cost',hue='Channel_Used',palette='Set2')
plt.title('Distribution of Acquisition_Cost vs Customer_Segment by Channel_Used',color='red',fontsize=20)
plt.xlabel('Customer_Segment',color='red',fontsize=20)
plt.ylabel('Acquisition_Cost',color='red',fontsize=20)
plt.show()

# %% [markdown]
# **Explanation:**
#
# * X-axis represents Customer_segment.
# * Y-axis represents Acquitision_Cost
# * It shows the boxplot visualize the distribution of Acquisition_Cost across each Customer_Segment,categorized by Channel_Used.
# * All the customer segments are more or less equal using of channel by the same acquitision cost.

# %% [markdown]
# **➢ Analyze average Conversion_Rate by Language using a bar chart to compare the effectiveness of campaigns conducted in different languages.**

# %%
#analyze average conversion rate by langugae using bar chart

plt.figure(figsize=(10,6),facecolor='pink')
data.groupby('Language')['Conversion_Rate'].mean().plot(kind='bar',color='purple')
plt.xlabel('Language',color='red',fontsize=20)
plt.ylabel('Conversion_Rate',color='red',fontsize=20)
plt.title("Average Conversion_Rate by Language",color='red',fontsize=20)
plt.legend('Language')
plt.show()

# %% [markdown]
# **Explanation:**
#
# * X-axis represents Customer_segment.
# * Y-axis represents Acquitision_Cost.
# * It shows the barchart for average conversion_rate by using language
# * In this chart we understand the average coversion rate is high when using english language compare with other languages.

# %% [markdown]
# **Channel Effectiveness:**
#
# **➢Compare the Engagement_Score for different Channels_Used, segmented by Campaign_Type, using a bar chart.**

# %%
#Compare the Engagement_Score for different Channels_Used, segmented by Campaign_Type using a bar chart.

plt.figure(figsize=(10,6),facecolor='pink')
sns.barplot(data,x='Channel_Used',y='Engagement_Score',hue='Campaign_Type',palette='Set2')
plt.title('Engagement_Score vs Channels_Used by Campaign_Type',color='red',fontsize=20)
plt.xlabel('Channel_Used',color='red',fontsize=20)
plt.ylabel('Engagement_Score',color='red',fontsize=20)
plt.show()

# %% [markdown]
# **Explanation:**
#
# * X-axis represents Channel_Used.
# * Y-axis represents Engagement_Score.
# * It shows the barchart to comapre the Engagement_Score for different Channels_Used, segmented by Campaign_Type.
# * In this barchart all the channels are getting high and equal enagegment score by the campaign type of social media

# %% [markdown]
# **➢ Show the distribution of total ROI across different Channels_Used using a pie chart.**

# %%
# distribution of ROI in different channel_used using a pie chart

data_pie=data.groupby('Channel_Used')['ROI'].sum()
plt.figure(figsize=(10,6),facecolor='pink')
plt.pie(data_pie,autopct='%1.2f%%',startangle=90,labels=data_pie.index,colors=['orange','blue','green','red','purple','brown'])
plt.title('Sum of ROI vs Channel_Used',color='red')
plt.show()

# %% [markdown]
# **Expalnation:**
#
# * This pie chart shows the distribution of total ROI across different Channels_Used.
# * The total of ROI is high for the use of facebook by the customers.

# %% [markdown]
# **➢ Plot a scatter plot to show the relationship between Clicks and Impression for each Channel_Used.**

# %%
#relationship between Clicks and Impression for each Channel_Used using scatter plot

plt.figure(figsize=(10,6),facecolor='pink')
plt.scatter(data['Channel_Used'],data['Clicks'],color='red')
plt.xlabel('Channel_Used',fontsize=25,color='purple')
plt.ylabel('Clicks and Impression',fontsize=25,color='purple')
plt.title('Clicks vs Channel_Used',fontsize=25,color='purple')
plt.grid(True)
plt.show()

# %% [markdown]
# **Explanation:**
#
# * X-axis represents Channel_Used
# * Y-axis represents Clicks and impression
# * It shows the scatter plot for the clicks and impression if the customer by using channels
# * Above visual shows there is high clicks and impression for the use of facebook,website,Google ads and youtube by the customer.

# %% [markdown]
# **Time-Based Analysis:**
#
# **➢ Plot the distribution of Duration using a histogram.**

# %% [markdown]
# In the dataframe duartions are in the categorical so we convert into numerical by the label encoder

# %%
#convert duration into numeric value

from sklearn.preprocessing import LabelEncoder

data_encoded=data.copy()

Label_encoder = LabelEncoder()

data_encoded['Duration']=Label_encoder.fit_transform(data_encoded['Duration'])

data_encoded['Duration']
# Out:
# 0        1
# 1        2
# 2        2
# 3        2
# 4        1
#         ..
# 22024    1
# 22025    2
# 22026    1
# 22027    2
# 22028    1
# Name: Duration, Length: 22029, dtype: int64

# %%
# distribution of Duration using a histogram
plt.figure(figsize=(10,6),facecolor='pink')
sns.histplot(data_encoded['Duration'],bins=5,color='pink',edgecolor='black',kde=True)
plt.title('Distribution of Duration',color='red',fontsize=20)
plt.xlabel('Duration',color='red',fontsize=20)
plt.ylabel('Count',color='red',fontsize=20)
plt.show()

# %% [markdown]
# Explanation:
#
# * X-axis representsDuration
# * Y-axis represents Count
# * It shows the histogram of distribution of  the duration.
# * we convert the duration categorical to numerical with help of label encoder
# * The encoder duration splited like short time,median time and long time
# * Over all this histogram we understand the count of the skew is high in the median time of duration.

# %% [markdown]
# **➢Analyze how the overall Conversion_Rate has changed over Date for each Company using a line chart.**

# %%
#Analyze the overall Conversion_Rate has changed over Date for each Company using a line chart

data['Date'] = pd.to_datetime(data['Date'],format='%d-%m-%Y')

plt.figure(figsize=(10,6),facecolor='pink')
sns.lineplot(data=data,x='Date',y='Conversion_Rate',hue='Company',errorbar=None,marker='*',markerfacecolor='red')
plt.title('Conversion_Rate over the date',color='red',fontsize=20)
plt.xlabel('Date',color='red',fontsize=20)
plt.ylabel('Coversion_Rate',color='red',fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# **EXPLANATION:**
#
#
# * X-axis represents Date
# * Y-axis represents conversion_rate
# * It shows the scatter plot for the date and conversion rate by campaign type
# * This visual shows all the company are more or less equal of the average conversion rate in the date of all year.
# * But at the time of 2023 month 7 to 8 the company of Tech Crop is getting highest averge conversion rate

# %% [markdown]
# **➢Examine the trend of Engagement_Score over Date with a line chart.**

# %%
# examine engagement score over date using lineplot


data['Date'] = pd.to_datetime(data['Date'],format='%d-%m-%Y')

plt.figure(figsize=(10,6),facecolor='pink')
sns.lineplot(data=data,x='Date',y='Engagement_Score',errorbar=None,marker='o',markerfacecolor='green',markersize='10')
plt.title('Engagement_Score over the date',color='red',fontsize=20)
plt.xlabel('Date',color='red',fontsize=20)
plt.ylabel('Engagement_Score',color='red',fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Explanation:**
#
# * X-axis represents Date
# * Y -axis represents Engagement_Score
# * It shows the line plot for date vs engagement score
# * It visuals zig zag line it means when the date and year high that time the engagement score also getting high

# %% [markdown]
# **Geographic Analysis:**
#
# **➢Determine which location has the highest Acquisition_Cost using a bar chart.**

# %%
# location vs acquitision cost using bar chart

plt.figure(figsize=(10,6),facecolor='pink')
sns.barplot(data,x='Location',y='Acquisition_Cost',hue='Location',palette='Set2')
plt.xticks(rotation=45)
plt.title('Location vs Acquisition_Cost',color='red',fontsize=20)
plt.xlabel('Location',color='red',fontsize=20)
plt.ylabel('Acuitision_Cost',color='red',fontsize=20)
plt.show()

# %% [markdown]
# **EXPLANATION:**
#
# * X-axis represents Location
# * Y-axis represents Acquitision_Cost
# * It shows the bar plot for location vs acquitision cost
# * The acquitision cost is high when the location of Newyork

# %% [markdown]
# **➢Visualize the Conversion_Rate by different Location,categorized by** **Target_Audience, using a bar chart.**

# %%
#Visualize the Conversion_Rate by different Location,categorized by Target_Audience, using a bar chart

plt.figure(figsize=(10,6),facecolor='pink')
sns.barplot(data,x='Location',y='Conversion_Rate',hue='Target_Audience',palette='Set3')
plt.xlabel('Location',color='red',fontsize=20)
plt.ylabel('Conversion_Rate',color='red',fontsize=20)
plt.title('Conversion_Rate by different Location by Target_Audience',color='red',fontsize=20)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **EXPALNATION:**
#
# * X-axis represents Location
# * Y-axis represents Conversion_reate
# * It shows the bar chart for location vs conversion rate by the target audience
# * In this visuals the audience of men 18 to 24 in the location of sanfrancisco is getting highest conversion_rate compare with others.

# %% [markdown]
# **➢Illustrate the proportion of ROI by Location using a pie chart.**

# %%
# ROI by location using piechart


plt.figure(figsize=(10,6),facecolor='pink')
data_pie=data.groupby('Location')['ROI'].sum()
plt.pie(data_pie,autopct='%1.2f%%',startangle=90,labels=data_pie.index)
plt.tight_layout()
plt.title('ROI by Location',color='red',fontsize=20)
plt.show()

# %% [markdown]
# **EXPLANATION:**This pie chart shows the ROI by location.On this the total ROI is high in the loction of chicago.

# %% [markdown]
# **CONCLUSION**:This project conducted a comprehensive analysis of marketing campaign performance, leveraging data visualization and statistical techniques. Here are the key findings and insights that can be derived from the analysis:
#
# * Campaign Performance
# * Customer segmentation
# * Channel effectiveness
# * Time-Base analysis
# * Geographic analysis
#
# Using these analysis we clearly understand the persormance of marketing_campaigns.
#
# **Recommendations:**
#
# * Optimize campaigns to minimize acquisition costs while maximizing ROI.
# Prioritize YouTube and social media channels for campaign delivery, with a particular focus on Facebook.
# * Tailor messaging and content to the identified high-performing customer segments, especially women aged 25 to 34.
# * Consider seasonal trends when scheduling campaigns to capitalize on periods of high conversion rates.
# * Conduct further analysis in the New York market to identify opportunities for improvement.
# * Continue monitoring campaign performance and customer behavior across different segments, channels, and locations to make data-driven decisions for future marketing strategies.
#
# These recommendations can be used to guide future marketing efforts and enhance the effectiveness of campaigns to achieve better results.
